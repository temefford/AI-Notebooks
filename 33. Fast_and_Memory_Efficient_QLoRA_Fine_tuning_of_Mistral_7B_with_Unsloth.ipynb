# %% [markdown]
# This notebook shows how to fine-tuning Mistral 7B with unsloth.
#
# The first section shows how to do it with recent GPUs (Ampere or more recent), such as the A100 of Colab. Jump to the Non-Ampere GPU section if you want to use an older GPU such as the T4.

# %% [markdown]
# First, we need to know which version of CUDA we are using to install the optimized version of unsloth.

# %%
import torch; torch.version.cuda
# Out:
# '12.1'

# %% [markdown]
# Using an Ampere GPU with CUDA 12.1, we need to install the version cu121_ampere of unsloth:

# %%
# !pip install "unsloth[cu121_ampere] @ git+https://github.com/unslothai/unsloth.git"
# Out:
# Collecting unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git
#   Cloning https://github.com/unslothai/unsloth.git to /tmp/pip-install-iz452p8c/unsloth_db3b147ed93c4385af78610355429f3c
#   Running command git clone --filter=blob:none --quiet https://github.com/unslothai/unsloth.git /tmp/pip-install-iz452p8c/unsloth_db3b147ed93c4385af78610355429f3c
#   Resolved https://github.com/unslothai/unsloth.git to commit 24133feda65a6996a1fd242ac8f9fc237a3befe5
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting bitsandbytes (from unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading bitsandbytes-0.41.3.post2-py3-none-any.whl (92.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 18.0 MB/s eta 0:00:00
# Collecting flash-attn (from unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading flash_attn-2.4.2.tar.gz (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 92.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from flash-attn->unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git) (2.1.0+cu121)
# Collecting einops (from flash-attn->unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading einops-0.7.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 7.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from flash-attn->unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git) (23.2)
# Collecting ninja (from flash-attn->unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 35.3 MB/s eta 0:00:00
# Collecting xformers@ https://download.pytorch.org/whl/cu121/xformers-0.0.22.post7-cp310-cp310-manylinux2014_x86_64.whl (from unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading https://download.pytorch.org/whl/cu121/xformers-0.0.22.post7-cp310-cp310-manylinux2014_x86_64.whl (211.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.8/211.8 MB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git) (4.35.2)
# Collecting datasets (from unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading datasets-2.16.0-py3-none-any.whl (507 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.1/507.1 kB 49.8 MB/s eta 0:00:00
# Collecting sentencepiece (from unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 77.0 MB/s eta 0:00:00
# Collecting accelerate (from unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading accelerate-0.25.0-py3-none-any.whl (265 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 36.4 MB/s eta 0:00:00
# Collecting trl (from unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading trl-0.7.7-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.1/139.1 kB 21.8 MB/s eta 0:00:00
# Collecting peft (from unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading peft-0.7.1-py3-none-any.whl (168 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.3/168.3 kB 22.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate->unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git) (1.23.5)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate->unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate->unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git) (6.0.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate->unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git) (0.19.4)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate->unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git) (0.4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn->unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn->unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn->unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn->unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn->unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn->unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->flash-attn->unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git) (2.1.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git) (10.0.1)
# Collecting pyarrow-hotfix (from datasets->unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Collecting dill<0.3.8,>=0.3.0 (from datasets->unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 18.6 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets->unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets->unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git) (4.66.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets->unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git) (3.4.1)
# Collecting multiprocess (from datasets->unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 20.1 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git) (3.9.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git) (2023.6.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers->unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git) (0.15.0)
# Collecting tyro>=0.5.11 (from trl->unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading tyro-0.6.2-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 11.3 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets->unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets->unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets->unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets->unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git) (2023.11.17)
# Collecting docstring-parser>=0.14.1 (from tyro>=0.5.11->trl->unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading docstring_parser-0.15-py3-none-any.whl (36 kB)
# Requirement already satisfied: rich>=11.1.0 in /usr/local/lib/python3.10/dist-packages (from tyro>=0.5.11->trl->unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git) (13.7.0)
# Collecting shtab>=1.5.6 (from tyro>=0.5.11->trl->unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading shtab-1.6.5-py3-none-any.whl (13 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->flash-attn->unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git) (2023.3.post1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->flash-attn->unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets->unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro>=0.5.11->trl->unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro>=0.5.11->trl->unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro>=0.5.11->trl->unsloth[cu121_ampere]@ git+https://github.com/unslothai/unsloth.git) (0.1.2)
# Building wheels for collected packages: flash-attn, unsloth
#   Building wheel for flash-attn (setup.py) ... done
#   Created wheel for flash-attn: filename=flash_attn-2.4.2-cp310-cp310-linux_x86_64.whl size=113714653 sha256=560df8869000f20f44af8ff42721c3d08ccfe5624bdc3c00e056a783e2a54fb9
#   Stored in directory: /root/.cache/pip/wheels/9d/cf/7f/d14555553b5b30698dae0a4159fdd058157e7021cec565ecaa
#   Building wheel for unsloth (pyproject.toml) ... done
#   Created wheel for unsloth: filename=unsloth-2024.1-py3-none-any.whl size=46547 sha256=6b6e0ebf0879f6127d2e4281fd1a337a2c5c0a52ce2b3704ea8e6b37922680cd
#   Stored in directory: /tmp/pip-ephem-wheel-cache-xzfe_6y5/wheels/ed/d4/e9/76fb290ee3df0a5fc21ce5c2c788e29e9607a2353d8342fd0d
# Successfully built flash-attn unsloth
# Installing collected packages: sentencepiece, ninja, bitsandbytes, unsloth, shtab, pyarrow-hotfix, einops, docstring-parser, dill, multiprocess, xformers, tyro, flash-attn, accelerate, datasets, trl, peft
# Successfully installed accelerate-0.25.0 bitsandbytes-0.41.3.post2 datasets-2.16.0 dill-0.3.7 docstring-parser-0.15 einops-0.7.0 flash-attn-2.4.2 multiprocess-0.70.15 ninja-1.11.1.1 peft-0.7.1 pyarrow-hotfix-0.6 sentencepiece-0.1.99 shtab-1.6.5 trl-0.7.7 tyro-0.6.2 unsloth-2024.1 xformers-0.0.22.post7

# %% [markdown]
# It installs all the dependencies. We can then import them:

# %%
import torch
from unsloth import FastLanguageModel
from datasets import load_dataset
from transformers import TrainingArguments
from trl import SFTTrainer
# Out:
# /usr/local/lib/python3.10/dist-packages/unsloth/__init__.py:67: UserWarning: CUDA is not linked properly.
# We shall run `ldconfig /usr/lib64-nvidia` to try to fix it.
#   warnings.warn(

# %% [markdown]
# FastLanguageModel.from_pretrained loads the model and its tokenizer.

# %%
model_name = "mistralai/Mistral-7B-v0.1"

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = model_name,
    max_seq_length = 512,
    dtype = None,
    load_in_4bit = True,
)
# Out:
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# ==((====))==  Unsloth: Fast Mistral patching release 2023.12
#    \\   /|    GPU: NVIDIA A100-SXM4-40GB. Max memory: 39.564 GB
# O^O/ \_/ \    CUDA capability = 8.0. Xformers = 0.0.22.post7. FA = True.
# \        /    Pytorch version: 2.1.0+cu121. CUDA Toolkit = 12.1
#  "-____-"     bfloat16 = TRUE. Platform = Linux
# model.safetensors.index.json:   0%|          | 0.00/25.1k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.94G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/967 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/72.0 [00:00<?, ?B/s]

# %% [markdown]
# Then, we add LoRA. I only add for the MLP modules: "gate_proj", "up_proj", "down_proj"

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r = 16,
    target_modules = ["gate_proj", "up_proj", "down_proj"],
    lora_alpha = 16,
    lora_dropout = 0, # Currently only supports dropout = 0
    bias = "none",    # Currently only supports bias = "none"
    use_gradient_checkpointing = True,
    random_state = 3407,
    max_seq_length = 512,
)
# Out:
# Unsloth 2023.12 patched 32 layers with 0 QKV layers, 0 O layers and 32 MLP layers.

# %% [markdown]
# Training arguments are standard:

# %%
training_arguments = TrainingArguments(
        output_dir="./unsloth_results",
        evaluation_strategy="steps",
        do_eval=True,
        per_device_train_batch_size=4,
        gradient_accumulation_steps=6,
        per_device_eval_batch_size=4,
        log_level="debug",
        save_steps=100,
        logging_steps=25,
        learning_rate=2e-4,
        eval_steps=50,
        optim='adamw_8bit',
        bf16=True, #change to fp16 if not using an Ampere GPU
        weight_decay=0.1,
        max_steps=500,
        warmup_ratio=0.01,
        lr_scheduler_type="linear",
)

# %% [markdown]
# Load the dataset used for fine-tuning:

# %%
dataset = load_dataset("timdettmers/openassistant-guanaco")
# Out:
# Downloading readme:   0%|          | 0.00/395 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/repocard.py:105: UserWarning: Repo card metadata block was not found. Setting CardData to empty.
#   warnings.warn("Repo card metadata block was not found. Setting CardData to empty.")
# Downloading data:   0%|          | 0.00/20.9M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.11M [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]

# %% [markdown]
# Fine-tuning with TRL's SFTTrainer:

# %%
trainer = SFTTrainer(
        model=model,
        train_dataset=dataset['train'],
        eval_dataset=dataset['test'],
        dataset_text_field="text",
        max_seq_length=512,
        tokenizer=tokenizer,
        args=training_arguments,
)

trainer.train()
# Out:
# Map:   0%|          | 0/9846 [00:00<?, ? examples/s]
# Map:   0%|          | 0/518 [00:00<?, ? examples/s]
# max_steps is given, it will override any value given in num_train_epochs
# Using auto half precision backend
# Currently training with a batch size of: 4
# ***** Running training *****
#   Num examples = 9,846
#   Num Epochs = 2
#   Instantaneous batch size per device = 4
#   Total train batch size (w. parallel, distributed & accumulation) = 24
#   Gradient Accumulation steps = 6
#   Total optimization steps = 500
#   Number of trainable parameters = 28,311,552
# You're using a LlamaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# Unsloth: `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`
#     <div>
#
#       <progress value='500' max='500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [500/500 31:53, Epoch 1/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>1.124100</td>
#       <td>1.148698</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.126700</td>
#       <td>1.141217</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>1.099600</td>
#       <td>1.138670</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>1.091500</td>
#       <td>1.134471</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>1.089300</td>
#       <td>1.131233</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>1.114500</td>
#       <td>1.128209</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>1.081400</td>
#       <td>1.126775</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>1.091300</td>
#       <td>1.125081</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.987800</td>
#       <td>1.128103</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>1.003200</td>
#       <td>1.128946</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 4
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 4
# Saving model checkpoint to ./unsloth_results/checkpoint-100
# tokenizer config file saved in ./unsloth_results/checkpoint-100/tokenizer_config.json
# Special tokens file saved in ./unsloth_results/checkpoint-100/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 4
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 4
# Saving model checkpoint to ./unsloth_results/checkpoint-200
# tokenizer config file saved in ./unsloth_results/checkpoint-200/tokenizer_config.json
# Special tokens file saved in ./unsloth_results/checkpoint-200/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 4
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 4
# Saving model checkpoint to ./unsloth_results/checkpoint-300
# tokenizer config file saved in ./unsloth_results/checkpoint-300/tokenizer_config.json
# Special tokens file saved in ./unsloth_results/checkpoint-300/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 4
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 4
# Saving model checkpoint to ./unsloth_results/checkpoint-400
# tokenizer config file saved in ./unsloth_results/checkpoint-400/tokenizer_config.json
# Special tokens file saved in ./unsloth_results/checkpoint-400/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 4
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 4
# Saving model checkpoint to ./unsloth_results/checkpoint-500
# tokenizer config file saved in ./unsloth_results/checkpoint-500/tokenizer_config.json
# Special tokens file saved in ./unsloth_results/checkpoint-500/special_tokens_map.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=500, training_loss=1.0917891845703125, metrics={'train_runtime': 1921.0503, 'train_samples_per_second': 6.247, 'train_steps_per_second': 0.26, 'total_flos': 2.5001061360176333e+17, 'train_loss': 1.0917891845703125, 'epoch': 1.22})

# %% [markdown]
# For comparison, this is the code I used for fine-tuning without unsloth:

# %%
import torch
from datasets import load_dataset
from peft import LoraConfig, prepare_model_for_kbit_training
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    AutoTokenizer,
    TrainingArguments,
)
from trl import SFTTrainer
model_name = "mistralai/Mistral-7B-v0.1"
#Tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name, use_fast=True)
tokenizer.pad_token = tokenizer.unk_token
tokenizer.pad_token_id =  tokenizer.unk_token_id
tokenizer.padding_side = 'left'

compute_dtype = getattr(torch, "bfloat16")
bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=compute_dtype,
        bnb_4bit_use_double_quant=True,
)
model = AutoModelForCausalLM.from_pretrained(
          model_name, quantization_config=bnb_config, device_map={"": 0}
)


model = prepare_model_for_kbit_training(model)
peft_config = LoraConfig(
        lora_alpha=16,
        lora_dropout=0.0,
        r=16,
        bias="none",
        task_type="CAUSAL_LM",
        target_modules= ["gate_proj", "up_proj", "down_proj"]
)

dataset = load_dataset("timdettmers/openassistant-guanaco")

training_arguments = TrainingArguments(
        output_dir="./drive/MyDrive/unsloth_results2",
        evaluation_strategy="steps",
        do_eval=True,
        per_device_train_batch_size=4,
        gradient_accumulation_steps=6,
        per_device_eval_batch_size=4,
        log_level="debug",
        save_steps=100,
        logging_steps=25,
        learning_rate=2e-4,
        eval_steps=50,
        optim='adamw_8bit',
        bf16=True, #change to fp16 if not using an Ampere GPU
        weight_decay=0.1,
        max_steps=500,
        warmup_ratio=0.01,
        lr_scheduler_type="linear",
)

trainer = SFTTrainer(
        model=model,
        train_dataset=dataset['train'],
        eval_dataset=dataset['test'],
        peft_config=peft_config,
        dataset_text_field="text",
        max_seq_length=512,
        tokenizer=tokenizer,
        args=training_arguments,
)

trainer.train()
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/repocard.py:105: UserWarning: Repo card metadata block was not found. Setting CardData to empty.
#   warnings.warn("Repo card metadata block was not found. Setting CardData to empty.")
# Map:   0%|          | 0/518 [00:00<?, ? examples/s]
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:282: UserWarning: You passed a tokenizer with `padding_side` not equal to `right` to the SFTTrainer. This might lead to some unexpected behaviour due to overflow issues when training a model in half-precision. You might consider adding `tokenizer.padding_side = 'right'` to your code.
#   warnings.warn(
# max_steps is given, it will override any value given in num_train_epochs
# Using auto half precision backend
# Currently training with a batch size of: 4
# ***** Running training *****
#   Num examples = 9,846
#   Num Epochs = 2
#   Instantaneous batch size per device = 4
#   Total train batch size (w. parallel, distributed & accumulation) = 24
#   Gradient Accumulation steps = 6
#   Total optimization steps = 500
#   Number of trainable parameters = 28,311,552
# You're using a LlamaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`...
#     <div>
#
#       <progress value='500' max='500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [500/500 1:06:35, Epoch 1/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>1.141100</td>
#       <td>1.163480</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.134200</td>
#       <td>1.146146</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>1.102700</td>
#       <td>1.140601</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>1.093000</td>
#       <td>1.136812</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>1.130700</td>
#       <td>1.185034</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>1.156300</td>
#       <td>1.153719</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>1.090200</td>
#       <td>1.134425</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>1.095700</td>
#       <td>1.131040</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>1.005700</td>
#       <td>1.134104</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>1.025500</td>
#       <td>1.135155</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 4
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 4
# Saving model checkpoint to ./drive/MyDrive/unsloth_results2/checkpoint-100
# tokenizer config file saved in ./drive/MyDrive/unsloth_results2/checkpoint-100/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/unsloth_results2/checkpoint-100/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 4
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 4
# Saving model checkpoint to ./drive/MyDrive/unsloth_results2/checkpoint-200
# tokenizer config file saved in ./drive/MyDrive/unsloth_results2/checkpoint-200/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/unsloth_results2/checkpoint-200/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 4
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 4
# Saving model checkpoint to ./drive/MyDrive/unsloth_results2/checkpoint-300
# tokenizer config file saved in ./drive/MyDrive/unsloth_results2/checkpoint-300/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/unsloth_results2/checkpoint-300/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 4
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 4
# Saving model checkpoint to ./drive/MyDrive/unsloth_results2/checkpoint-400
# tokenizer config file saved in ./drive/MyDrive/unsloth_results2/checkpoint-400/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/unsloth_results2/checkpoint-400/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 4
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 4
# Saving model checkpoint to ./drive/MyDrive/unsloth_results2/checkpoint-500
# tokenizer config file saved in ./drive/MyDrive/unsloth_results2/checkpoint-500/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/unsloth_results2/checkpoint-500/special_tokens_map.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=500, training_loss=1.1072690620422363, metrics={'train_runtime': 4002.947, 'train_samples_per_second': 2.998, 'train_steps_per_second': 0.125, 'total_flos': 2.5001061360176333e+17, 'train_loss': 1.1072690620422363, 'epoch': 1.22})

# %% [markdown]
# # *Non* Ampere GPU (T4)
#
# The following QLoRA fine-tuning is the same as above but without bfloat16 and using the cu121 version of unsloth.

# %%
# !pip install "unsloth[cu121] @ git+https://github.com/unslothai/unsloth.git"
# Out:
# Collecting unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git
#   Cloning https://github.com/unslothai/unsloth.git to /tmp/pip-install-suof1hsm/unsloth_ec0a51ef3d274815b155a322ce6ca9c9
#   Running command git clone --filter=blob:none --quiet https://github.com/unslothai/unsloth.git /tmp/pip-install-suof1hsm/unsloth_ec0a51ef3d274815b155a322ce6ca9c9
#   Resolved https://github.com/unslothai/unsloth.git to commit 0369e7aa7ad67e1f9e59ecbc98306f4f19afb0b3
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting bitsandbytes (from unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading bitsandbytes-0.41.3.post2-py3-none-any.whl (92.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 19.3 MB/s eta 0:00:00
# Collecting xformers@ https://download.pytorch.org/whl/cu121/xformers-0.0.22.post7-cp310-cp310-manylinux2014_x86_64.whl (from unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading https://download.pytorch.org/whl/cu121/xformers-0.0.22.post7-cp310-cp310-manylinux2014_x86_64.whl (211.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.8/211.8 MB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git) (4.35.2)
# Collecting datasets (from unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading datasets-2.16.0-py3-none-any.whl (507 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.1/507.1 kB 52.0 MB/s eta 0:00:00
# Collecting sentencepiece (from unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 70.5 MB/s eta 0:00:00
# Collecting accelerate (from unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading accelerate-0.25.0-py3-none-any.whl (265 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 32.6 MB/s eta 0:00:00
# Collecting trl (from unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading trl-0.7.7-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.1/139.1 kB 21.8 MB/s eta 0:00:00
# Collecting peft (from unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading peft-0.7.1-py3-none-any.whl (168 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.3/168.3 kB 21.0 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git) (23.2)
# Collecting ninja (from unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 39.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate->unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git) (1.23.5)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate->unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate->unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate->unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git) (2.1.0+cu121)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate->unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git) (0.19.4)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate->unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git) (0.4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets->unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git) (3.13.1)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git) (10.0.1)
# Collecting pyarrow-hotfix (from datasets->unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Collecting dill<0.3.8,>=0.3.0 (from datasets->unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 19.6 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets->unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets->unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git) (4.66.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets->unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git) (3.4.1)
# Collecting multiprocess (from datasets->unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 19.9 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets->unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git) (3.9.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git) (2023.6.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers->unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git) (0.15.0)
# Collecting tyro>=0.5.11 (from trl->unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading tyro-0.6.2-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 12.7 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate->unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate->unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate->unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate->unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate->unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git) (2.1.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets->unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets->unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets->unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets->unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git) (2023.11.17)
# Collecting docstring-parser>=0.14.1 (from tyro>=0.5.11->trl->unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading docstring_parser-0.15-py3-none-any.whl (36 kB)
# Requirement already satisfied: rich>=11.1.0 in /usr/local/lib/python3.10/dist-packages (from tyro>=0.5.11->trl->unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git) (13.7.0)
# Collecting shtab>=1.5.6 (from tyro>=0.5.11->trl->unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading shtab-1.6.5-py3-none-any.whl (13 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets->unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro>=0.5.11->trl->unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro>=0.5.11->trl->unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git) (2.16.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate->unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate->unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro>=0.5.11->trl->unsloth[cu121]@ git+https://github.com/unslothai/unsloth.git) (0.1.2)
# Building wheels for collected packages: unsloth
#   Building wheel for unsloth (pyproject.toml) ... done
#   Created wheel for unsloth: filename=unsloth-2024.1-py3-none-any.whl size=46250 sha256=adc4c88f448810aeb23039f1a859dc2a496f137a7d8d318f9b108e79c2163fae
#   Stored in directory: /tmp/pip-ephem-wheel-cache-mh9v4xxl/wheels/ed/d4/e9/76fb290ee3df0a5fc21ce5c2c788e29e9607a2353d8342fd0d
# Successfully built unsloth
# Installing collected packages: sentencepiece, ninja, bitsandbytes, unsloth, shtab, pyarrow-hotfix, docstring-parser, dill, multiprocess, xformers, tyro, accelerate, datasets, trl, peft
# Successfully installed accelerate-0.25.0 bitsandbytes-0.41.3.post2 datasets-2.16.0 dill-0.3.7 docstring-parser-0.15 multiprocess-0.70.15 ninja-1.11.1.1 peft-0.7.1 pyarrow-hotfix-0.6 sentencepiece-0.1.99 shtab-1.6.5 trl-0.7.7 tyro-0.6.2 unsloth-2024.1 xformers-0.0.22.post7

# %%
from unsloth import FastLanguageModel
from datasets import load_dataset
from transformers import (
    TrainingArguments,
)
from trl import SFTTrainer

model_name = "mistralai/Mistral-7B-v0.1"

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = model_name,
    max_seq_length = 512,
    dtype = None,
    load_in_4bit = True,
)
model = FastLanguageModel.get_peft_model(
    model,
    r = 16,
    target_modules = ["gate_proj", "up_proj", "down_proj"],
    lora_alpha = 16,
    lora_dropout = 0, # Currently only supports dropout = 0
    bias = "none",    # Currently only supports bias = "none"
    use_gradient_checkpointing = True,
    random_state = 3407,
    max_seq_length = 512,
)

training_arguments = TrainingArguments(
        output_dir="./unsloth_results_t4",
        evaluation_strategy="steps",
        do_eval=True,
        per_device_train_batch_size=4,
        gradient_accumulation_steps=6,
        per_device_eval_batch_size=4,
        log_level="debug",
        save_steps=100,
        logging_steps=50,
        learning_rate=2e-4,
        eval_steps=50,
        optim='adamw_8bit',
        fp16=True, #change to fp16 if not using an Ampere GPU
        weight_decay=0.1,
        max_steps=500,
        warmup_ratio=0.01,
        lr_scheduler_type="linear",
)

dataset = load_dataset("timdettmers/openassistant-guanaco")

trainer = SFTTrainer(
        model=model,
        train_dataset=dataset['train'],
        eval_dataset=dataset['test'],
        dataset_text_field="text",
        max_seq_length=512,
        tokenizer=tokenizer,
        args=training_arguments,
)

trainer.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/unsloth/__init__.py:67: UserWarning: CUDA is not linked properly.
# We shall run `ldconfig /usr/lib64-nvidia` to try to fix it.
#   warnings.warn(
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# ==((====))==  Unsloth: Fast Mistral patching release 2023.12
#    \\   /|    GPU: Tesla T4. Max memory: 14.748 GB
# O^O/ \_/ \    CUDA capability = 7.5. Xformers = 0.0.22.post7. FA = False.
# \        /    Pytorch version: 2.1.0+cu121. CUDA Toolkit = 12.1
#  "-____-"     bfloat16 = FALSE. Platform = Linux
# model.safetensors.index.json:   0%|          | 0.00/25.1k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.94G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/967 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/72.0 [00:00<?, ?B/s]
# Unsloth 2023.12 patched 32 layers with 0 QKV layers, 0 O layers and 32 MLP layers.
# Downloading readme:   0%|          | 0.00/395 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/repocard.py:105: UserWarning: Repo card metadata block was not found. Setting CardData to empty.
#   warnings.warn("Repo card metadata block was not found. Setting CardData to empty.")
# Downloading data:   0%|          | 0.00/20.9M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.11M [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Map:   0%|          | 0/9846 [00:00<?, ? examples/s]
# Map:   0%|          | 0/518 [00:00<?, ? examples/s]
# max_steps is given, it will override any value given in num_train_epochs
# Using auto half precision backend
# Currently training with a batch size of: 4
# ***** Running training *****
#   Num examples = 9,846
#   Num Epochs = 2
#   Instantaneous batch size per device = 4
#   Total train batch size (w. parallel, distributed & accumulation) = 24
#   Gradient Accumulation steps = 6
#   Total optimization steps = 500
#   Number of trainable parameters = 28,311,552
# You're using a LlamaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# Unsloth: `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`
#     <div>
#
#       <progress value='251' max='500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [251/500 2:20:16 < 2:20:16, 0.03 it/s, Epoch 0.61/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>1.158900</td>
#       <td>1.148608</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.120600</td>
#       <td>1.140937</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>1.119200</td>
#       <td>1.138291</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>1.097200</td>
#       <td>1.134411</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>1.093500</td>
#       <td>1.130968</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 4
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 4
# Saving model checkpoint to ./unsloth_results_t4/checkpoint-100
# tokenizer config file saved in ./unsloth_results_t4/checkpoint-100/tokenizer_config.json
# Special tokens file saved in ./unsloth_results_t4/checkpoint-100/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 4
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 4
# Saving model checkpoint to ./unsloth_results_t4/checkpoint-200
# tokenizer config file saved in ./unsloth_results_t4/checkpoint-200/tokenizer_config.json
# Special tokens file saved in ./unsloth_results_t4/checkpoint-200/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 4
#     <div>
#
#       <progress value='500' max='500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [500/500 4:48:32, Epoch 1/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>1.158900</td>
#       <td>1.148608</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.120600</td>
#       <td>1.140937</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>1.119200</td>
#       <td>1.138291</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>1.097200</td>
#       <td>1.134411</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>1.093500</td>
#       <td>1.130968</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>1.116800</td>
#       <td>1.128115</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>1.103300</td>
#       <td>1.126570</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>1.082900</td>
#       <td>1.124936</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>1.015400</td>
#       <td>1.127879</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>1.007500</td>
#       <td>1.128644</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 4
# Saving model checkpoint to ./unsloth_results_t4/checkpoint-300
# tokenizer config file saved in ./unsloth_results_t4/checkpoint-300/tokenizer_config.json
# Special tokens file saved in ./unsloth_results_t4/checkpoint-300/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 4
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 4
# Saving model checkpoint to ./unsloth_results_t4/checkpoint-400
# tokenizer config file saved in ./unsloth_results_t4/checkpoint-400/tokenizer_config.json
# Special tokens file saved in ./unsloth_results_t4/checkpoint-400/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 4
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 4
# Saving model checkpoint to ./unsloth_results_t4/checkpoint-500
# tokenizer config file saved in ./unsloth_results_t4/checkpoint-500/tokenizer_config.json
# Special tokens file saved in ./unsloth_results_t4/checkpoint-500/special_tokens_map.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=500, training_loss=1.0915244064331056, metrics={'train_runtime': 17339.8068, 'train_samples_per_second': 0.692, 'train_steps_per_second': 0.029, 'total_flos': 2.5001061360176333e+17, 'train_loss': 1.0915244064331056, 'epoch': 1.22})
